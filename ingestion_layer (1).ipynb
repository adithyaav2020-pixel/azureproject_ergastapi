# %%
import requests

url = "https://api.openf1.org/v1/drivers?session_key=latest"

response = requests.get(url)

data = response.json()

print(data[:5])
# Out:
# [{'meeting_key': 1287, 'session_key': 11307, 'driver_number': 1, 'broadcast_name': 'L NORRIS', 'full_name': 'Lando NORRIS', 'name_acronym': 'NOR', 'team_name': 'McLaren', 'team_colour': 'F47600', 'first_name': 'Lando', 'last_name': 'Norris', 'headshot_url': 'https://media.formula1.com/d_driver_fallback_image.png/content/dam/fom-website/drivers/L/LANNOR01_Lando_Norris/lannor01.png.transform/1col/image.png', 'country_code': None}, {'meeting_key': 1287, 'session_key': 11307, 'driver_number': 3, 'broadcast_name': 'M VERSTAPPEN', 'full_name': 'Max VERSTAPPEN', 'name_acronym': 'VER', 'team_name': 'Red Bull Racing', 'team_colour': '4781D7', 'first_name': 'Max', 'last_name': 'Verstappen', 'headshot_url': 'https://media.formula1.com/d_driver_fallback_image.png/content/dam/fom-website/drivers/M/MAXVER01_Max_Verstappen/maxver01.png.transform/1col/image.png', 'country_code': None}, {'meeting_key': 1287, 'session_key': 11307, 'driver_number': 5, 'broadcast_name': 'G BORTOLETO', 'full_name': 'Gabr
# ...

# %%
import pandas as pd

pdf = pd.DataFrame(data)

display(pdf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df = spark.createDataFrame(pdf)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# ADLS access permission
storage_account = "<storage_account_name>"
access_key = "<storage_account_key"

spark.conf.set(
    f"fs.azure.account.key.{storage_account}.dfs.core.windows.net",
    access_key
)

# %%
# Read Data from OpenF1 API
import requests
url = "https://api.openf1.org/v1/drivers?session_key=latest"
data = requests.get(url).json()
print(f"Records fetched: {len(data)}")
# Out:
# Records fetched: 22

# %%
# Convert JSON to Spark Dataframe
import pandas as pd
pdf = pd.DataFrame(data)
pdf = pdf.fillna("")
df = spark.createDataFrame(pdf)
display(df)

df.printSchema()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dbutils.fs.ls("abfss://raw@driverf1storageprject.dfs.core.windows.net/")
# Out:
# [FileInfo(path='abfss://raw@driverf1storageprject.dfs.core.windows.net/drivers/', name='drivers/', size=0, modificationTime=1781253427000)]

# %%
df.write \
  .format("delta") \
  .mode("overwrite") \
  .save("abfss://raw@driverf1storageprject.dfs.core.windows.net/drivers")

# %%
dbutils.fs.ls("abfss://raw@driverf1storageprject.dfs.core.windows.net/drivers")
# Out:
# [FileInfo(path='abfss://raw@driverf1storageprject.dfs.core.windows.net/drivers/_delta_log/', name='_delta_log/', size=0, modificationTime=1781253427000),
#  FileInfo(path='abfss://raw@driverf1storageprject.dfs.core.windows.net/drivers/part-00000-0a6aceab-2827-43f1-8232-7fd2c62b5db9.c000.snappy.parquet', name='part-00000-0a6aceab-2827-43f1-8232-7fd2c62b5db9.c000.snappy.parquet', size=6289, modificationTime=1781253432000),
#  FileInfo(path='abfss://raw@driverf1storageprject.dfs.core.windows.net/drivers/part-00000-0ef3b199-c5b6-4609-bcb4-6983fe2ee986.c000.snappy.parquet', name='part-00000-0ef3b199-c5b6-4609-bcb4-6983fe2ee986.c000.snappy.parquet', size=6494, modificationTime=1781926764000),
#  FileInfo(path='abfss://raw@driverf1storageprject.dfs.core.windows.net/drivers/part-00000-308b00b2-28ff-44a2-b975-138ed744c671.c000.snappy.parquet', name='part-00000-308b00b2-28ff-44a2-b975-138ed744c671.c000.snappy.parquet', size=6494, modificationTime=1781581192000),
# ...

# %%
df = spark.read.format("delta").load(
    "abfss://raw@driverf1storageprject.dfs.core.windows.net/drivers"
)

# %%
dbutils.fs.ls("/")
# Out:
# [FileInfo(path='dbfs:/Volumes/', name='Volumes/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/Workspace/', name='Workspace/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks/', name='databricks/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/', name='databricks-datasets/', size=0, modificationTime=0)]

# %%
raw_path = "abfss://raw@driverf1storageprject.dfs.core.windows.net/drivers"

df = spark.read.format("delta").load(raw_path)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
